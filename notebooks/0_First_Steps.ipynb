# %%
# !which python
# !which pip
# !which uv
# Out:
# /opt/conda/envs/maic/bin/python
# /opt/conda/envs/maic/bin/pip
# /opt/conda/envs/maic/bin/uv

# %%
# !uv pip install numpy pandas opencv-python-headless openslide-python tqdm matplotlib torch torchvision albumentations timm scikit-learn segmentation-models-pytorch
# Out:
# Using Python 3.10.19 environment at: /opt/conda/envs/maic
# Resolved 71 packages in 775ms
# Prepared 39 packages in 1.98s
# Installed 39 packages in 49ms
#  + albucore==0.0.24
#  + albumentations==2.0.8
#  + annotated-types==0.7.0
#  + anyio==4.12.0
#  + certifi==2026.1.4
#  + click==8.3.1
#  + contourpy==1.3.2
#  + cycler==0.12.1
#  + fonttools==4.61.1
#  + h11==0.16.0
#  + hf-xet==1.2.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + huggingface-hub==1.2.3
#  + idna==3.11
#  + joblib==1.5.3
#  + kiwisolver==1.4.9
#  + matplotlib==3.10.8
#  + opencv-python-headless==4.12.0.88
#  + openslide-python==1.4.3
#  + pandas==2.3.3
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + pyparsing==3.3.1
#  + pytz==2025.2
#  + pyyaml==6.0.3
#  + safetensors==0.7.0
#  + scikit-learn==1.7.2
#  + scipy==1.15.3
#  + segmentation-models-pytorch==0.5.0
#  + shellingham==1.5.4
#  + simsimd==6.5.12
#  + stringzilla==4.6.0
#  + threadpoolctl==3.6.0
#  + timm==1.0.22
#  + tqdm==4.67.1
# ...
